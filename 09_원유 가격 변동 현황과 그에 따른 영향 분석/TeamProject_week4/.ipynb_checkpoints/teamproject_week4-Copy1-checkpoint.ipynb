# %%
# 모듈 생성
import csv
import platform
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# 'C:\\hcb\\pandas_study\\week4\\TeamProject'

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 0AA0-A41A
#
#  C:\hcb\pandas_study\week4\TeamProject 디렉터리
#
# 2022-07-20  오전 09:20    <DIR>          .
# 2022-07-20  오전 09:20    <DIR>          ..
# 2022-07-20  오전 09:20    <DIR>          .ipynb_checkpoints
# 2022-07-20  오전 09:20             2,533 2조 발표 제안서.ipynb
# 2022-07-20  오전 09:14             8,865 4주차 팀플_전처리.ipynb
# 2022-07-20  오전 08:42            79,246 4주차_팀플 (일단 옮김 완료).ipynb
# 2022-07-20  오전 08:52    <DIR>          data
# 2022-07-20  오전 02:42            21,585 flight_staff.ipynb
# 2022-07-20  오전 09:07    <DIR>          Fonts
# 2022-07-20  오전 09:05             2,311 sightseeing.ipynb
# 2022-07-20  오전 09:17            42,994 teamproject_week4 (원본).ipynb
# 2022-07-20  오전 09:18            42,944 teamproject_week4-Copy1.ipynb
#                7개 파일             200,478 바이트
#                5개 디렉터리  172,225,937,408 바이트 남음

# %% [markdown]
# ### 연간 국제 유가 데이터 file

# %%
inter_oil_price_year = pd.read_csv('./data/inter_oil_price_year.csv', encoding='utf-8')
inter_oil_price_year.columns
inter_oil_price_year
# inter_oil_price_year['유가']
# Out:
#     연도          유가
# 0   12  715.837538
# 1   13  716.119679
# 2   14  635.935833
# 3   15  361.830046
# 4   16  315.390772
# 5   17  376.262744
# 6   18  475.866206
# 7   19  451.288213
# 8   20  307.388137
# 9   21  501.496667
# 10  22  799.833350

# %% [markdown]
# ### 연도별 국제 항공수송실적 file

# %%
inter_air_trans = pd.read_csv('./data/inter_air_trans_year_01.csv', encoding='euc_kr')
print(inter_air_trans.columns)
inter_air_trans.head()
# Out:
# Index(['구분', '여객(명)', '여객킬로(Km)', '화물(톤)', '화물톤킬로(Km)', '운항(회)', '운항킬로(Km)'], dtype='object')
#      구분       여객(명)        여객킬로(Km)    화물(톤)      화물톤킬로(Km)   운항(회)  \
# 0  1989   8,283,164  29,795,423,539  711,295  4,268,280,900  44,219
# 1  1990   9,626,415  36,405,075,593  776,759  4,554,913,269  53,442
# 2  1991  10,270,666  38,521,435,036  787,342  4,470,003,436  59,927
# 3  1992  11,257,011  45,220,452,753  837,215  4,968,222,114  66,363
# 4  1993  11,651,345  47,627,320,253  950,574  6,182,815,941  68,615
#
#       운항킬로(Km)
# 0  212,959,283
# 1  249,721,301
# 2  267,728,140
# 3  307,090,481
# 4  324,066,393

# %%
# 필요없는 행과 열 삭제
inter_air_trans.drop(['여객킬로(Km)','화물톤킬로(Km)','운항킬로(Km)'], axis=1, inplace=True)
inter_air_trans.drop(labels=range(0, 23), axis = 0, inplace=True)
inter_air_trans
# Out:
#       구분       여객(명)      화물(톤)    운항(회)
# 23  2012  47,702,644  3,208,780  313,726
# 24  2013  50,986,891  3,246,253  338,988
# 25  2014  56,778,759  3,410,742  366,485
# 26  2015  61,434,404  3,518,772  388,008
# 27  2016  73,000,810  3,780,908  438,856
# 28  2017  76,955,719  4,031,516  457,099
# 29  2018  85,925,288  4,168,783  497,089
# 30  2019  90,385,640  4,015,987  528,243
# 31  2020  14,239,922  3,070,993  167,211
# 32  2021   3,208,695  3,420,163  131,442

# %%
# 컬럼명 수정
inter_air_trans.rename({'구분':'연도','유가': '유가(원/배럴)'}, axis=1, inplace=True)

# %%
# 인덱스 정리
inter_air_trans_1 = inter_air_trans.set_index('연도')
inter_air_trans = inter_air_trans_1.reset_index()

# %%
inter_air_trans
# Out:
#      연도       여객(명)      화물(톤)    운항(회)
# 0  2012  47,702,644  3,208,780  313,726
# 1  2013  50,986,891  3,246,253  338,988
# 2  2014  56,778,759  3,410,742  366,485
# 3  2015  61,434,404  3,518,772  388,008
# 4  2016  73,000,810  3,780,908  438,856
# 5  2017  76,955,719  4,031,516  457,099
# 6  2018  85,925,288  4,168,783  497,089
# 7  2019  90,385,640  4,015,987  528,243
# 8  2020  14,239,922  3,070,993  167,211
# 9  2021   3,208,695  3,420,163  131,442

# %% [markdown]
# ### 연간 등록 숙박시설 file

# %%
stay_regit_year_2021 = pd.read_csv('./data/stay_regit_year_2021.csv', encoding='euc_kr', skiprows=3)
stay_regit_year_2021.drop(['Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18'], axis=1, inplace=True)
stay_regit_year_2021
# Out:
#              Unnamed: 0 Unnamed: 1        소계       호텔업   휴양콘도미니엄업    관광펜션업   \
# 0     2012년\n(12.31기준)        업체수      2,036       786        180      297
# 1                   NaN       (%)        4.3        NaN        NaN      NaN
# 2                   NaN       객실수    126,760    82,209     38,971    2,640
# 3                   NaN       (%)       16.2        NaN        NaN      NaN
# 4     2013년\n(12.31기준)        업체수      2,666       896        192      332
# ..                  ...        ...        ...       ...        ...      ...
# 430                 NaN       객실수     33,889    23,871      9,105      913
# 431   2020년\n(12.31.기준)       업체수        422       363         59        -
# 432                 NaN       객실수     29,228    20,195      9,033        -
# 433   2021년\n(12.31.기준)       업체수        423       362         60        -
# 434                 NaN       객실수     33,665    24,573      9,089        -
#
#       한옥체험업   외국인도시민박업          계      일반숙박업     생활숙박업    농어촌민박업     유스호스텔   \
# 0       516        257     26,319     25,453       866    18,398       108
# 1        NaN        NaN      56.1         NaN       NaN     39.2       0.2
# 2     2,255        685    577,186    557,209    19,977    68,219    10,959
# 3        NaN        NaN      73.7         NaN       NaN      8.7       1.4
# 4       695        551     26,828     25,659     1,169    20,047       112
# ..       ...        ...        ...        ...       ...       ...       ...
# 430       -          -     26,872     20,426     6,446    12,429       917
# 431       -          -        835        649       186     4,484        19
# 432       -          -     27,419     20,295     7,124    12,566       917
# 433       1          -        866        647       219     4,750        17
# 434       3          -     29,165     21,663     7,502    12,957       804
#
#      휴양펜션업  Unnamed: 14
# 0       59      46,920
# 1      0.1       100.0
# 2      504     783,628
# 3      0.1        99.9
# 4       79      49,732
# ..      ...         ...
# 430    913      75,020
# 431    108       5,868
# 432    932      71,062
# 433    110       6,166
# 434    942      77,533
#
# [435 rows x 15 columns]

# %%
# 필요한 자료를 얻기 위해 컬럼 정리
stay_regit_year_2021 = stay_regit_year_2021.iloc[0:40:4]

# %%
# 컬럼명 정리
stay_regit_year_2021 = stay_regit_year_2021.rename({'Unnamed: 0':'연도','Unnamed: 1':'업체수','계':'소계','Unnamed: 14':'총계'}, axis=1)
stay_regit_year_2021

# 인덱스 정리
stay_regit_year_2021 = stay_regit_year_2021.set_index('연도')
stay_regit_year_2021 = stay_regit_year_2021.reset_index()

# %%
# 10년치 연도 리스트 담아둔 것
ten_year = []
for i in range(2012, 2022):
    ten_year.append(str(i))
ten_year
# Out:
# ['2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
# 연도 컬럼 정리
stay_regit_year_2021['연도'] = ten_year

# 총계 컬럼만 떼어 내야겠다고 판단
stay_regit_year_2021_total = stay_regit_year_2021['총계']

# %%
# 총계(업체수) 컬럼 추가
inter_air_trans['총 업체수'] = stay_regit_year_2021_total

# %%
# 컬럼명 정리
inter_air_trans = inter_air_trans.rename({'총 업체수':'숙박 업체수(개)'}, axis=1)
inter_air_trans
# Out:
#      연도       여객(명)      화물(톤)    운항(회) 숙박 업체수(개)
# 0  2012  47,702,644  3,208,780  313,726   46,920
# 1  2013  50,986,891  3,246,253  338,988   49,732
# 2  2014  56,778,759  3,410,742  366,485   53,777
# 3  2015  61,434,404  3,518,772  388,008   56,915
# 4  2016  73,000,810  3,780,908  438,856   58,591
# 5  2017  76,955,719  4,031,516  457,099   59,995
# 6  2018  85,925,288  4,168,783  497,089   62,045
# 7  2019  90,385,640  4,015,987  528,243   62,957
# 8  2020  14,239,922  3,070,993  167,211   62,212
# 9  2021   3,208,695  3,420,163  131,442   68,773

# %%
# 데이터들 타입 정리
inter_air_trans['여객(명)'] = inter_air_trans['여객(명)'].str.replace(',','').astype('int')
inter_air_trans['화물(톤)'] = inter_air_trans['화물(톤)'].str.replace(',','').astype('int')
inter_air_trans['운항(회)'] = inter_air_trans['운항(회)'].str.replace(',','').astype('int')
inter_air_trans['숙박 업체수(개)'] = inter_air_trans['숙박 업체수(개)'].str.replace(',','').astype('int')

# %%
# 정리된 DF, csv로 저장 => 소수의 경우, 소수점 2번째까지 나타나도록 파일을 내보냄
inter_air_trans.to_csv('C:\hcb\pandas_study\week4\TeamProject\data\inter_air_trans_fin.csv', index=False, float_format = '%.2f')

# %%
# 이외 다른 파일들 전처리 과정은 한군데 몰아서 실시, csv 파일로 보낸 것들 불러오기

# %% [markdown]
# ### 남은 파일 불러오기 (국내 항공 운송 현황, 업체별 항공 종사자 file)

# %%
sightseeing = pd.read_csv('./data/sightseeing_fin.csv', encoding='utf-8')
inter_air_trans_2 = pd.read_csv('./data/inter_air_trans_2_fin.csv', encoding='utf-8')

# %% [markdown]
# ## 그래프 분석
# ## 1) 항공사
#
# ### (1) 유가의 변동과 여객/화물/운항의 변동

# %%
# 유가 컬럼 추가
# inter_oil_price_year = inter_oil_price_year.drop(10)
aa = inter_oil_price_year['유가'].tolist()
inter_air_trans['유가'] = aa

# %%
inter_air_trans
# Out:
#      연도     여객(명)    화물(톤)   운항(회)  숙박 업체수(개)          유가
# 0  2012  47702644  3208780  313726      46920  715.837538
# 1  2013  50986891  3246253  338988      49732  716.119679
# 2  2014  56778759  3410742  366485      53777  635.935833
# 3  2015  61434404  3518772  388008      56915  361.830046
# 4  2016  73000810  3780908  438856      58591  315.390772
# 5  2017  76955719  4031516  457099      59995  376.262744
# 6  2018  85925288  4168783  497089      62045  475.866206
# 7  2019  90385640  4015987  528243      62957  451.288213
# 8  2020  14239922  3070993  167211      62212  307.388137
# 9  2021   3208695  3420163  131442      68773  501.496667

# %%
b = inter_air_trans['연도'].tolist()
x1 = inter_air_trans['여객(명)'].tolist()
x2 = inter_air_trans['화물(톤)'].tolist()
x3 = inter_air_trans['운항(회)'].tolist()
y = inter_air_trans['유가'].tolist()
