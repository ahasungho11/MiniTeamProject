# %%
import pandas as pd

DIR_PATH = '../Data/'
FILE_NAME = DIR_PATH+'sports_Daegu_2020.xlsx'
FILE_NAME
# Out:
# '../Data/sports_Daegu_2020.xlsx'

# %%
# 데이터프레임 저장 - 서울 체육시설 현황(2020)
sports_Daegu = pd.read_excel(FILE_NAME, sheet_name=None, skiprows=1)  # 각 시트의 이름이 key, 시트의 내용이 value인 딕셔너리
sports_Daegu
# Out:
# {'표지':        Unnamed: 0
#  0             NaN
#  1             NaN
#  2             NaN
#  3             NaN
#  4             NaN
#  5             NaN
#  6     (2019년말 기준)
#  7             NaN
#  8             NaN
#  9             NaN
#  10            NaN
#  11            NaN
#  12            NaN
#  13            NaN
#  14           2020
#  15            NaN
#  16            NaN
#  17            NaN
#  18            NaN
#  19            NaN
#  20  문 화 체 육 관 광 부,
#  '일반개요':                                            Unnamed: 0
#  0    ㅇ 본 통계는 "체육시설의 설치ㆍ이용에 관한 법률" 제36조(시책 수립에 필요한 ...
#  1                                                 NaN
#  2                                         2. 체육시설의 정의
#  3                                                 NaN
#  4                                           가. 학문적 정의
#  5       ㅇ 효과적이며 보다 쾌적하고 안전한 운동활동을 전제로 설치 관리되는 일정한 ...
#  6         - 광의적 개념 : 운동에 필요한 물적인 여러가지 조건을 인공적으로 정비...
#  7                          - 협의적 개념 : 운동학습을 위한 각종의 장소
# ...

# %%
# 변수 정리
# sports_Daegu : 파일에 포함된 모든 시트를 불러온 것
# Daegu_list_all : 모든 시트의 이름을 뽑아서 리스트에 담은 것
# Daegu_list : 정보를 뽑을 시트 이름만을 모아 놓은 리스트
# Daegu_condition : 엑셀 파일 내에 있는 요약된 정보 시트명
# Daegu_col : 해당 시트에서 뽑을 컬럼명만을 모아 놓은 리스트

# %%
Daegu_list_all = list(sports_Daegu.keys())
Daegu_list_all
# Out:
# ['표지',
#  '일반개요',
#  '공공체육시설의분류기준',
#  '연도별현황',
#  '설치주체별현황',
#  '시도별현황',
#  '육상경기장',
#  '축구장',
#  '하키장',
#  '야구장',
#  '싸이클경기장',
#  '테니스장',
#  '씨름장',
#  '구기체육관',
#  '투기체육관',
#  '생활체육관',
#  '게이트볼장',
#  '수영장',
#  '롤러스케이트장',
#  '사격장',
#  '국궁장',
#  '양궁장',
#  '승마장',
#  '골프연습장',
#  '조정카누장',
#  '요트장',
#  '빙상장',
#  '스키점프경기장',
#  '바이애슬론경기장',
#  '크로스컨트리경기장',
#  '봅슬레이,루지,스켈레톤경기장',
#  '기타 체육시설']

# %%
Daegu_list = Daegu_list_all[3:24]
Daegu_list
# Out:
# ['연도별현황',
#  '설치주체별현황',
#  '시도별현황',
#  '육상경기장',
#  '축구장',
#  '하키장',
#  '야구장',
#  '싸이클경기장',
#  '테니스장',
#  '씨름장',
#  '구기체육관',
#  '투기체육관',
#  '생활체육관',
#  '게이트볼장',
#  '수영장',
#  '롤러스케이트장',
#  '사격장',
#  '국궁장',
#  '양궁장',
#  '승마장',
#  '골프연습장']

# %%
Daegu_condition = sports_Daegu[Daegu_list[3]]
Daegu_condition
# Out:
#      일련번호   시도   시군구       주소             시설명         소유기관   운영조직(연락처)  \
# 0     NaN  NaN   NaN      NaN             NaN          NaN         NaN
# 1     NaN  NaN   NaN      NaN             NaN          NaN         NaN
# 2     NaN   전국     계      NaN             252          NaN         NaN
# 3     NaN   서울  소  계      NaN               3          NaN         NaN
# 4     1.0  NaN   양천구  안양천길336           목동운동장          서울시  서울시시설관리사업소
# ..    ...  ...   ...      ...             ...          ...         ...
# 267   NaN  NaN  서귀포시      NaN   남원생활체육관\n주경기장  제주특별\n자 치 도         NaN
# 268   NaN  NaN  서귀포시      NaN  대정문화체육센터\n주경기장  제주특별\n자 치 도         NaN
# 269   NaN  NaN  서귀포시      NaN   안덕생활체육관\n주경기장  제주특별\n자 치 도         NaN
# 270   NaN  NaN  서귀포시      NaN   표선생활체육관\n주경기장  제주특별\n자 치 도         NaN
# 271   NaN  NaN  서귀포시      NaN  성산국민체육센터\n주경기장  제주특별\n자 치 도         NaN
#
#               Unnamed: 7         관리주체 관리인원  ... Unnamed: 53 Unnamed: 54  \
# ...

# %%
Daegu_condition = sports_Daegu[Daegu_list[6]]
Daegu_condition
# Out:
#     일련번호   시도   시군구           주소                시설명       소유기관   운영조직(연락처)  \
# 0    NaN  NaN   NaN          NaN                NaN        NaN         NaN
# 1    NaN  NaN   NaN          NaN                NaN        NaN         NaN
# 2    NaN   전국     계          NaN                309        NaN         NaN
# 3    NaN   서울  소  계          NaN                 19        NaN         NaN
# 4      1  NaN    중구          NaN            장충리틀야구장        서울시         NaN
# ..   ...  ...   ...          ...                ...        ...         ...
# 331  NaN  NaN   제주시  오라1동 1163-4       제주 주경기장\n야구장  제주특별\n자치도  종합경기장관리사무소
# 332  NaN  NaN   제주시          NaN        동복리체육센터 야구장  제주특별\n자치도         NaN
# 333  NaN  NaN  서귀포시  오라1동 1163-4  제주공천포전지훈련센터 \n야구장  제주특별\n자치도  종합경기장관리사무소
# 334  NaN  NaN  서귀포시  오라1동 1163-4             서귀포야구장  제주특별\n자치도  종합경기장관리사무소
# 335  NaN  NaN  서귀포시          NaN           서귀포생활야구장  제주특별\n자치도         NaN
#
# ...
