# %% [markdown]
# # < 최종 결론 >

# %% [markdown]
# [교육] 특수교육 자체의 만족도는 높으니, 지역사회와의 합의를 통해 증가하는 방향으로 방법 모색
# [고용] 과태료를 내게 되더라도, 장애인 고용이 이뤄지지 않고 있음. 고용장려금제도 등을 비롯 새로운 제도 시행을 위한 노력중
# [인식] 차별은 인식하고 있지만, 개선되지 않음. 무엇보다 인식 개선을 위한 교육의 중요성이 강조됨
# [장애인 학대] 사회, 기관, 개인 등 모든 주변 체계가 상호작용하여 복합적으로 발생

# %% [markdown]
# ### - 사회의 어떤 부분이든 서로 맞물려 원인이 되고, 결과가 되는 모습을 앞서 발표에서 볼 수 있었음.
# ### - <span style='background:yellow'> 인식</span>에 기반된다고 할 수 있음  =>  <span style='background:yellow'> 교육 중요성</span>

# %%
from IPython.display import Image
Image('img/wordC.jpg')

# %% [markdown]
# ### <span style = 'color : red'>  - 일시적인 관심x, 조금이라도 관심 </span>
