# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import datetime as dt
from dateutil.relativedelta import relativedelta
from selenium.webdriver.common.by import By
from konlpy.tag import Okt
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
import platform
import pandas as pd


# def openUrl(driver):
#     # 로그인 정보
#     login_url = 'https://nid.naver.com/nidlogin.login'
#     naver_id = "qweriii1977"
#     naver_pw = "fkfk2rj2@!##H"

#     # 드라이버 실행 후 로그인
#     driver.get(login_url)
#     driver.implicitly_wait(2)

#     # execute_script 함수 사용하여 자바스크립트로 id,pw 넘겨주기
#     driver.execute_script("document.getElementsByName('id')[0].value=\'" + naver_id + "\'")
#     driver.execute_script("document.getElementsByName('pw')[0].value=\'" + naver_pw + "\'")

#     # 로그인 버튼 클릭하기
#     driver.find_element(By.XPATH, '//*[@id="log.login"]').click()
#     time.sleep(1)

#     # 기기등록 버튼 클릭하기
#     driver.find_element(By.XPATH, '//*[@id="new.save"]').click()
#     time.sleep(1)

def createList(driver, item_title, item_date):
    now = dt.datetime.now()
    date = now

    while True:
        count = 1

        while True:
            # 크롤링 진행하려는 카페 주소(중고나라)
            cafe_url = '''
            https://cafe.naver.com/joonggonara?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=10050146%26search.
            menuid=440%26search.media=0%26search.searchdate={0}{1}%26search.defaultValue=1%26userDisplay=15%26search.
            onSale=1%26search.option=3%26search.sortBy=date%26search.searchBy=0%26search.searchBlockYn=0%26search.
            query=kg%26search.viewtype=title%26search.page={2}
            '''.format(dt.datetime.strftime(date - dt.timedelta(days=6), '%Y-%m-%d'), dt.datetime.strftime(date, '%Y-%m-%d'), count)

            driver.get(cafe_url)

            # iframe으로 접근
            driver.switch_to.frame('cafe_main')
            soup = BeautifulSoup(driver.page_source, 'html.parser')

            # 네이버 카페 구조 확인후 게시글 내용만 가저오기
            datas = soup.find_all(class_='td_article')
            dates = soup.find_all(class_='td_date')

            if datas == []:
                break

            for data in datas:
                article_title = data.find(class_='article')
                article_title = article_title.get_text().strip()
                item_title.append(article_title)

            for day in dates: item_date.append(day.text)

            count += 1

        date = date - dt.timedelta(weeks=1)
        if date < (now - relativedelta(years=2)): break

def createCSV(item_title, item_date):
    data = {'Title': item_title, 'Date': item_date}
    df = pd.DataFrame(data)
    df.drop_duplicates(['Title'], ignore_index=True, inplace=True)
    df.to_csv('item_list.csv', encoding='utf-8-sig')

####-----------------------------------------------------------------

def draw_wordcloud():
    item_title = []
    item_date = []

    driver = webdriver.Chrome('C:\workspace\chromedriver')
    
    openUrl(driver)
    createList(driver, item_title, item_date)
    createCSV(item_title, item_date)
    
    ###############
    okt = Okt()
    tags = []
    ###############

    for txt in item_title:
        sentences_tag = okt.pos(txt)
        # tag가 명사인 단어들만 noun_adj_list에 넣어준다.
        for word, tag in sentences_tag:
            if tag in ['Noun']:
                tags.append(word)

    # print(okt_nouns)
    print(tags)

    # # 가장 많이 나온 단어부터 40개를 저장한다.
    counts = Counter(tags)
    print(counts)
    tags = counts.most_common(100)
    print(tags)

    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin': # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'

    wc = WordCloud(font_path=path, background_color="white", max_font_size=60)
    cloud = wc.generate_from_frequencies(dict(tags))
    print(cloud)
    
    # 생성된 WordCloud를 test.jpg로 보낸다.
    #cloud.to_file('test.jpg')
    plt.figure(figsize=(10, 8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()
    
draw_wordcloud()
# Out:
# C:\Users\ahasu\AppData\Local\Temp\ipykernel_18224\460333494.py:92: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\workspace\chromedriver')
# ['우레', '중량', '원판', '에프', '몬스터', '캡틴아메리카', '부산', '해운대', '기장', '직거래', '차', '할인', '아령', '가성', '비', '홈짐', '와이드', '미니', '랙', '세트', '렛', '타워', '벤치', '중량', '봉', '포함', '분해', '완료', '아이언', '렉스', '하프', '랙', '각도', '조절', '벤치', '더스', '크랙', '더스크제', '우레', '원판', '판매', '디랙', '스', '익스', '텐션', '디랙', '스', '로터리', '토르', '소', '판매', '덤벨', '경량', '원판', '조립', '덤벨', '판매', '짱짱', '랙', '중량', '봉', '원판', '벤치', '덤벨', '덤벨', '정리', '및', '덤벨', '세트', '신품', '아미', '코스', '당', '원판', '정리', '및', '원판', '세트', '신품', '아미', '코스', '당', '경량', '원판', '당', '천원', '고정식', '아령', '우레', '아령', '각', '아령', '각', '아령', '중고', '아령', '신품', '아령', '구형', '파워', '텍', '레버리지', '짐', '고무', '원판', '바벨', '헬스', '가격', '고진', '마에스트로', '정리', '클럽', '벨', '홈짐', '정리', '로', '버스', '트', '원판', '알통', '스쿼트', '랙', '우레', '바벨', '에프', '몬스터', '퀵블럭랙', '하프', '렉', '하프', '랙', '원판', '바벨', '덤벨', '아이언', '불', '홈짐', '정리', '로', '버스', '트', '원판', '알통', '스쿼트', '랙', '우레', '바벨', '바디', '엑스', '파워', '렉', '홈짐', '세트', '판매', '크롬', '경량', '바벨', '덤벨', '원판', '개', '아이', '핏펀', '덤벨', '급처', '홈짐', '용품', '우레', '원판', '시나', '브로', '파워리프팅', '바벨', '홈짐', '일괄', '판매', '외', '다수', '구매', '대비', '마테라', '원판', '홈짐', '스쿼트', '렉', '원판', '헬스', '원판', '개', '개', '개', '개', '개', '총', '원판', '각', '덤벨', '쌍', '판매', '스쿼트', '랙', '바디', '엑스', '중량', '봉', '씨', '케이', '중량', '원판', '씨', '케이', '대전', '직거래', '아령', '아이언', '불', '덤벨', '파워', '블럭', '파워', '블럭', '지바', '리프', '신형', '벤치', '알통', '스포츠', '홈짐', '일괄', '판매', '가격', '및', '본문', '하단', '참고', '덤벨', '중량', '아령', '우레', '덤벨', '판매', '리바', '제품', '로', '버스', '트', '덤벨', '아령', '초', '저가', '각', '우레', '원판', '장', '총', '판매', '헬스', '원판', '매트', '판매', '벤치', '프레', '스', '접이식', '벤치', '치닝디핑', '경량', '원판', '경량', '봉', '가격', '다운', '미니', '랙', '덤벨', '탄력', '봉', '원판', '등', '힘콩', '철봉', '치닝디핑', '플라이', '인클라인', '벤치', '중량', '봉', '원판', '경량', '손잡이', '원판', '당', '초', '처', '전부', '예약', '범', '퍼플', '레이', '트', '판매', '중량', '원판', '판매', '다이빙', '슈트', '써핑', '슈트', '홈짐', '판매', '인벤', '탑', '홈짐', '벤치', '데드', '랫풀', '딥스', '바벨', '바', '구성', '덤벨', '판매', '멀티', '미니', '랙', '및', '홈짐', '용품', '일괄', '원판', '덤벨', '판매', '홈트', '홈짐', '덤벨', '덤벨', '아령', '처분', '알통', '스포츠', '우레', '탄원', '판', '힘콩', '철봉', '치닝디핑', '플라이', '인클라인', '벤치', '중량', '봉', '원판', '원형', '덤벨', '당', '수량', '인벤', '탑', '홈짐', '확장', '랫', '타워', '헬스', '중량', '원판', '창원시', '중량', '원판', '경주', '대구', '경산', '포항', '인벤', '탑', '미니', '랙', '확장팩', '등', '홈짐', '정리', '아령', '바벨', '덤벨', '덤벨', '랙', '덤벨', '일괄', '덤벨', '랙', '덤벨', '덤벨', '덤벨', '랙', '일괄', '처분', '덤벨', '정리', '및', '덤벨', '세트', '원판', '정리', '및', '원판', '세트', '덤벨', '정리', '및', '덤벨', '세트', '원판', '정리', '및', '원판', '세트', '우레', '덤벨', '풀', '세트', '판매', '씨앤', '케이', '멀티', '미니', '랙', '풀셋트', '판매', '덤벨', '정리', '및', '덤벨', '세트', '원판', '정리', '및', '원판', '세트', '경량', '용', '원판', '인천', '인천', '시청역', '덤벨', '개', '개', '개', '판매', '스마트', '로드', '덤벨', '거의', '홈짐', '헬스', '기구', '일괄', '거울', '및', '벤치', '판매', '덤벨', '덤벨', '랙', '일괄', '판매', '운동', '기구', '헬스', '자전거', '목포', '헬스', '기구', '일괄', '개인', '런닝머신', '외', '개', '교체', '판매', '금액', '일괄', '광주', '원판', '판매', '스마트', '로드', '덤벨', '군산', '홈짐', '세트', '대전', '인벤', '탑', '미니', '렉', '운동', '기구', '벤치', '프레', '스', '로잉머신', '거', '꾸리', '커튼', '벨', '아령', '훌라우프', '일괄', '운동', '기구', '판매', '스쿼트', '렉', '벤치', '가능', '원판', '봉', '포함', '일괄', '판매', '중량', '원판', '아디다스', '캐틀벨', '원판', '덤벨', '세트', '판매', '플로', '그', '우레', '원판', '경량', '원판', '판매', '토탈', '벤치', '파워', '렉', '원판', '중량', '봉', '매트', '판매', '경량', '원판', '판매', '디', '오브', '경량', '중량', '원판', '에프', '몬스터', '알통', '더스', '크랙', '우레', '주물', '경량', '원판', '판매', '홈트', '웨이', '트', '중량', '종류', '별', '원판', '파이', '스쿼트', '랙', '바벨', '랙', '각도', '조절', '벤치', '해', '머스트', '렝스', '덤벨', '헬스장', '이전', '정리', '경량', '원판', '판매', '해', '머스트', '렝스', '카피', '덤벨', '파격', '일', '개별', '판매', '바디', '엑스', '풀', '세트', '해', '머스트', '렝스', '클럽', '용', '복근', '해', '머스트', '랭스', '카피', '덤벨', '경량', '원판', '판매', '나이키
': 1, '최저': 1, '택배': 1, '오산': 1, '궐': 1, '시': 1, '부평구': 1, '로망': 1, '체어': 1, '아쿠아': 1, '스쿠터': 1, '옥시즌': 1, '홈질': 1, '바이퍼': 1, '정도': 1, '프라자': 1, '덤밸': 1, '스텍스': 1, '태': 1, '원반': 1, '낱개': 1, '다이노': 1, '마스터': 1, '재고': 1, '영등포': 1, '스헬스': 1, '구직': 1, '모래주머니': 1, '미사': 1, '수정': 1, '몬': 1, '각각': 1, '용인': 1, '매희': 1, '레그': 1, '미제': 1, '기타': 1, '질': 1, '최고급': 1, '추럴': 1, '바나나': 1, '풀셋': 1, '소음': 1, '바이크': 1, '고정': 1, '양천구': 1, '용감': 1, '컴뱃': 1, '파우더': 1, '벤츠': 1, '뉴텍': 1, '블루': 1, '세분': 1, '티': 1, '리': 1, '스톤': 1, '컬': 1, '크런치': 1, '카보': 1, '말토': 1, '덱스트린': 1, '인하': 1, ' ...
# [('판매', 352), ('원판', 243), ('아령', 240), ('덤벨', 215), ('중량', 139), ('운동', 114), ('봉', 91), ('고무', 87), ('중고', 83), ('일괄', 83), ('코팅', 77), ('케틀벨', 76), ('신품', 74), ('기구', 71), ('등', 64), ('벤치', 63), ('바벨', 60), ('로잉머신', 57), ('트', 56), ('각종', 56), ('도구', 56), ('수직바', 56), ('랙', 50), ('경량', 48), ('홈짐', 46), ('피트니스', 44), ('각', 43), ('개별', 42), ('용', 41), ('우레', 38), ('세트', 38), ('스마트', 38), ('헬스', 37), ('자전거', 37), ('가정', 37), ('모비', 36), ('스피닝', 36), ('정리', 35), ('개', 31), ('위프', 31), ('실내', 31), ('당일', 28), ('쌍', 26), ('연동', 26), ('당', 24), ('조절', 23), ('직거래', 21), ('렉', 18), ('더', 18), ('머', 18), ('프로', 16), ('미니', 15), ('및', 15), ('스쿼트', 15), ('미개', 15), ('버팔로', 15), ('빅로', 15), ('팔', 15), ('나우', 14), ('너', 14), ('배송', 14), ('하프', 13), ('가격', 13), ('치닝디핑', 13), ('틴', 13), ('각도', 12), ('파워', 12), ('제품', 12), ('인클라인', 12), ('플레이', 12), ('머신', 12), ('에프', 11), ('구매', 11), ('무게', 11), ('다이어트', 11), ('몬스터', 10), ('스', 10), ('신형', 10), ('멀티', 10), ('카', 10), ('가성', 9), ('외', 9), ('프레', 9), ('웨이', 9), ('컬러', 9), ('상품', 9), ('플러그', 9), ('검정색', 9), ('완료', 8), ('블럭', 8), ('인벤', 8), ('탑', 8), ('탄원', 8), ('판', 8), ('대구', 8), ('마이', 8), ('볼', 8), ('알통', 7), ('바디', 7), ('용품', 7)]
# <wordcloud.wordcloud.WordCloud object at 0x000001D6FF867C70>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       1 # print(okt_nouns)
#       2 # print(tag)
#       3
#       4 # # 가장 많이 나온 단어부터 40개를 저장한다.
# ----> 5 counts = Counter(tags)
#       6 print(counts)
#       7 tags = counts.most_common(100)
#
# NameError: name 'tags' is not defined

# %%
inter_oil_price_year = pd.read_csv('./data/inter_oil_price_year.csv', encoding='utf-8')
